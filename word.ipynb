# %% [markdown]
# # Word to Vector

# %% [markdown]
# ## Load data
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# Download the data for the source website
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a string.

def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
# Build the dictionary and replace rare words with UNK token.

vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
# Function to generate a training batch for the skip-gram model.

data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'originated', 'a', 'of', 'originated', 'as', 'term']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.856710
# Nearest to they: gar, tentacle, evangelistic, castration, bcg, tutte, distilling, zef,
# Nearest to during: aims, generalised, spells, spinner, menace, infer, vertical, untersuchungen,
# Nearest to if: fluctuated, caucus, healy, rationalist, makes, task, insults, illuminati,
# Nearest to use: tartu, storytellers, hieroglyphs, phylum, reunification, paddock, castrated, emoticon,
# Nearest to is: prokaryote, eschenbach, dialling, kilobyte, oxfordshire, montenegrins, hotline, equal,
# Nearest to were: odor, jmp, speculator, cosmography, ethnically, released, adventist, missourians,
# Nearest to war: tolkien, unita, vegetable, chartres, bogdanovich, contraband, audiovisual, eithne,
# Nearest to which: planned, positivist, electrode, textual, treviso, denomination, salamanders, hosni,
# Nearest to zero: congresses, pius, missy, poz, featured, arguing, pilgrimages, frankly,
# Nearest to at: setter, shmuel, contae, furnishing, apprenticeship, drilling, conceived, colby,
# Nearest to about: wah, empirical, concurrency, replenished, chow, xbox, basques, amun,
# Nearest to a: chanel, divorced, chronos, refering, dhyana, magnetism, speedup, stitches,
# Nearest to s: nisan, armalite, bazille, ziggy, vedas, surface, resigns, plasmids,
# Nearest to will: raft, separation, belfast, ls, hamlets, ingersoll, carlisle, coincidence,
# Nearest to that: naturalisation, warhol, participate, finder, noncommercial, linger, rotation, executor,
# Nearest to time: micrometers, spleen, eyes, melos, ris, cvn, soliloquy, preamble,
# Average loss at step 2000: 4.375494
# Average loss at step 4000: 3.868870
# Average loss at step 6000: 3.794252
# Average loss at step 8000: 3.683357
# Average loss at step 10000: 3.616487
# Nearest to they: he, gar, it, you, that, not, who, castration,
# Nearest to during: after, spinner, spells, with, from, volunteer, generalised, in,
# Nearest to if: do, task, insults, vhf, illuminati, trophy, makes, fas,
# Nearest to use: reparations, ctor, tartu, storytellers, acetyl, misinterpretation, lexikon, lansing,
# Nearest to is: was, are, has, be, frisians, aud, manganese, census,
# Nearest to were: are, was, have, tenderness, is, cosmography, odor, rockies,
# Nearest to war: tolkien, affiliation, geckos, restorer, chartres, metabolic, allergy, audiovisual,
# Nearest to which: this, it, that, also, petri, there, tram, what,
# Nearest to zero: six, five, seven, nine, eight, four, three, two,
# Nearest to at: in, from, on, of, usc, synthesized, akshara, goran,
# Nearest to about: empirical, unanimity, wah, fasciculata, first, cancel, rose, seif,
# Nearest to a: the, this, no, pressed, sadi, pew, its, nonexistent,
# Nearest to s: his, and, or, punjab, polymorphism, the, abdomen, boehm,
# Nearest to will: would, augustinians, raft, coincidence, excretion, lefty, npc, foul,
# Nearest to that: which, it, rotation, they, but, this, howstuffworks, fes,
# Nearest to time: quantization, abused, ris, appearing, stalks, eyes, storefront, pursues,
# Average loss at step 12000: 3.612010
# Average loss at step 14000: 3.577987
# Average loss at step 16000: 3.411263
# Average loss at step 18000: 3.455914
# Average loss at step 20000: 3.542374
# Nearest to they: he, we, there, you, it, these, gar, who,
# Nearest to during: after, in, from, at, spinner, by, spells, through,
# Nearest to if: when, but, task, do, catamarans, did, makes, elevations,
# Nearest to use: reparations, ctor, trophy, noord, storytellers, confidence, telepathic, tanistry,
# Nearest to is: was, has, are, be, does, were, structuralist, hissarlik,
# Nearest to were: are, was, have, had, be, is, by, been,
# Nearest to war: tolkien, geckos, affiliation, culmination, restorer, respected, rumford, astrakhan,
# Nearest to which: that, this, it, but, these, also, who, what,
# Nearest to zero: five, six, three, seven, four, eight, nine, two,
# Nearest to at: in, from, during, on, merz, younger, celtics, janet,
# Nearest to about: unanimity, empirical, brl, fasciculata, denied, mccay, monteverdi, seif,
# Nearest to a: the, no, this, hovering, yakuza, mercenaries, pharyngeal, magnesians,
# Nearest to s: debugger, designations, filk, hyi, the, rub, balanchine, while,
# Nearest to will: would, can, could, may, to, should, npc, raft,
# Nearest to that: which, but, fes, drum, rotation, when, this, answered,
# Nearest to time: abused, quantization, period, commandments, day, ris, appearing, pursues,
# Average loss at step 22000: 3.504913
# Average loss at step 24000: 3.487826
# Average loss at step 26000: 3.478648
# Average loss at step 28000: 3.480880
# Average loss at step 30000: 3.504483
# Nearest to they: he, there, we, you, these, it, who, not,
# Nearest to during: after, in, through, from, by, at, techstep, between,
# Nearest to if: when, but, where, elevations, makes, task, catamarans, golding,
# Nearest to use: reparations, start, ctor, noord, ec, belated, slapping, level,
# Nearest to is: was, has, are, becomes, were, godlike, be, does,
# Nearest to were: are, was, have, had, by, is, be, centrally,
# Nearest to war: geckos, tolkien, approximately, affiliation, overthrow, astrakhan, rumford, aegisthus,
# Nearest to which: that, this, who, it, these, what, but, also,
# Nearest to zero: five, eight, seven, four, three, nine, six, two,
# Nearest to at: in, during, gangsta, acp, janet, near, on, dismayed,
# Nearest to about: unanimity, derek, imported, empirical, fasciculata, seif, eucharist, on,
# Nearest to a: no, the, hovering, any, divorced, fraction, principals, sadi,
# Nearest to s: clients, his, filk, salian, kummer, macrophages, debugger, chondrite,
# Nearest to will: would, can, could, may, should, shall, must, npc,
# Nearest to that: which, this, but, fes, what, rotation, answered, however,
# Nearest to time: abused, period, day, resembles, exceed, appearing, commandments, gather,
# Average loss at step 32000: 3.501814
# Average loss at step 34000: 3.494212
# Average loss at step 36000: 3.454770
# Average loss at step 38000: 3.299577
# Average loss at step 40000: 3.426288
# Nearest to they: we, he, you, there, it, these, she, not,
# Nearest to during: after, at, through, techstep, in, until, gary, since,
# Nearest to if: when, where, is, carp, describes, before, elevations, carbonic,
# Nearest to use: reparations, start, ctor, belated, ec, form, bernardi, jagger,
# Nearest to is: was, are, be, has, if, baryonic, godlike, becomes,
# Nearest to were: are, have, was, had, popov, while, be, been,
# Nearest to war: geckos, overthrow, foal, monoclonal, kathleen, looting, approximately, metabolic,
# Nearest to which: that, this, what, also, who, often, it, there,
# Nearest to zero: five, seven, nine, six, eight, three, four, two,
# Nearest to at: during, on, cadets, from, janet, dismayed, wilfrid, progressive,
# Nearest to about: unanimity, on, fasciculata, empirical, dylan, exhausts, tests, derek,
# Nearest to a: the, another, pew, any, exhausted, nonexistent, tame, bru,
# Nearest to s: his, roque, quietly, her, carefree, kummer, wic, slipper,
# Nearest to will: would, can, could, may, should, must, shall, npc,
# Nearest to that: which, what, this, however, because, but, organizers, where,
# Nearest to time: period, year, day, way, abused, sentiment, gather, advocated,
# Average loss at step 42000: 3.440030
# Average loss at step 44000: 3.456237
# Average loss at step 46000: 3.448956
# Average loss at step 48000: 3.358808
# Average loss at step 50000: 3.385171
# Nearest to they: he, there, we, you, it, she, these, prospective,
# Nearest to during: after, in, techstep, through, at, until, since, when,
# Nearest to if: when, where, before, though, describes, although, after, but,
# Nearest to use: reparations, start, form, ctor, basis, list, guru, rest,
# Nearest to is: was, are, has, does, became, becomes, be, contains,
# Nearest to were: are, have, was, had, be, those, been, these,
# Nearest to war: overthrow, geckos, foal, berthold, affiliation, looting, astrakhan, culmination,
# Nearest to which: that, this, also, what, who, often, aman, these,
# Nearest to zero: five, seven, eight, six, four, nine, three, two,
# Nearest to at: during, in, near, reith, spr, wilfrid, from, dismayed,
# Nearest to about: proclamations, eucharist, tests, fasciculata, unanimity, between, brl, mccay,
# Nearest to a: the, another, hovering, divorced, any, satirised, dreaming, enough,
# Nearest to s: whose, his, slipper, clients, zorn, consumes, carefree, chromosomal,
# Nearest to will: would, could, can, may, should, must, shall, might,
# Nearest to that: which, however, what, how, sliced, this, buttocks, drum,
# Nearest to time: year, day, period, sentiment, way, labourers, section, suda,
# Average loss at step 52000: 3.439319
# Average loss at step 54000: 3.427140
# Average loss at step 56000: 3.439829
# Average loss at step 58000: 3.392349
# Average loss at step 60000: 3.395251
# Nearest to they: we, there, you, he, she, these, quickly, it,
# Nearest to during: after, in, before, techstep, when, until, through, although,
# Nearest to if: when, where, before, though, although, describes, golding, after,
# Nearest to use: reparations, form, basis, start, ignoring, belated, guru, ctor,
# Nearest to is: was, are, although, becomes, does, has, be, godlike,
# Nearest to were: are, have, was, had, those, including, while, although,
# Nearest to war: overthrow, foal, geckos, astrakhan, berthold, culmination, kathleen, affiliation,
# Nearest to which: that, this, what, there, who, however, these, it,
# Nearest to zero: five, four, eight, six, seven, three, nine, two,
# Nearest to at: near, during, wilfrid, in, under, spr, piacenza, millionaires,
# Nearest to about: proclamations, eucharist, between, tests, michal, fasciculata, unanimity, treatise,
# Nearest to a: any, another, the, this, pew, no, enough, phenyl,
# Nearest to s: whose, resigns, hyi, his, hoc, filament, salian, puzzled,
# Nearest to will: would, could, can, may, must, should, shall, might,
# Nearest to that: which, however, what, this, there, it, buttocks, castrato,
# Nearest to time: year, day, period, sentiment, way, labourers, reuben, lionheart,
# Average loss at step 62000: 3.241792
# Average loss at step 64000: 3.251311
# Average loss at step 66000: 3.407107
# Average loss at step 68000: 3.396762
# Average loss at step 70000: 3.356555
# Nearest to they: we, he, there, you, it, she, quickly, these,
# Nearest to during: after, in, before, despite, until, techstep, through, at,
# Nearest to if: when, where, though, before, after, golding, can, while,
# Nearest to use: reparations, belated, start, basis, metrication, ignoring, rest, form,
# Nearest to is: was, has, are, be, although, becomes, contains, does,
# Nearest to were: are, have, was, had, be, those, while, been,
# Nearest to war: foal, overthrow, berthold, astrakhan, geckos, humphreys, kathleen, culmination,
# Nearest to which: that, this, what, however, also, but, these, syllabics,
# Nearest to zero: five, six, four, eight, seven, nine, three, two,
# Nearest to at: during, near, in, under, dismayed, spr, roughly, wilfrid,
# Nearest to about: on, proclamations, conjunct, that, dylan, chadian, treatise, michal,
# Nearest to a: the, another, enough, any, pew, bru, jackass, poker,
# Nearest to s: whose, dioscorus, mauser, slovenes, hyi, stricture, weavers, shadowed,
# Nearest to will: would, could, may, can, should, must, might, shall,
# Nearest to that: which, however, what, this, buttocks, but, lifting, delineated,
# Nearest to time: year, period, sentiment, day, labourers, happened, spicy, way,
# Average loss at step 72000: 3.371016
# Average loss at step 74000: 3.349648
# Average loss at step 76000: 3.315526
# Average loss at step 78000: 3.354565
# Average loss at step 80000: 3.376947
# Nearest to they: we, he, there, you, she, it, these, quickly,
# Nearest to during: after, in, when, before, despite, through, techstep, until,
# Nearest to if: when, though, before, where, although, after, golding, dz,
# Nearest to use: reparations, because, rest, form, belated, start, list, onslaught,
# Nearest to is: was, has, became, are, contains, does, remains, although,
# Nearest to were: are, was, had, have, those, be, being, been,
# Nearest to war: overthrow, foal, berthold, humphreys, infestation, looting, culmination, kathleen,
# Nearest to which: that, this, what, usually, also, but, who, often,
# Nearest to zero: seven, five, six, four, eight, three, nine, two,
# Nearest to at: in, during, once, near, under, on, after, cadets,
# Nearest to about: proclamations, dylan, conjunct, nine, deportivo, brl, unanimity, over,
# Nearest to a: another, the, jackass, composites, dreaming, hovering, pew, any,
# Nearest to s: isbn, kummer, whose, vonnegut, slipper, carl, nmos, boehm,
# Nearest to will: would, could, can, may, must, should, cannot, might,
# Nearest to that: which, however, buttocks, what, delineated, timestamp, this, answered,
# Nearest to time: year, day, sentiment, cooperstown, period, deferred, kidding, indictment,
# Average loss at step 82000: 3.415210
# Average loss at step 84000: 3.409775
# Average loss at step 86000: 3.392635
# Average loss at step 88000: 3.351543
# Average loss at step 90000: 3.365922
# Nearest to they: we, he, there, you, she, it, these, but,
# Nearest to during: after, in, before, techstep, although, at, while, when,
# Nearest to if: when, where, though, although, before, carbonic, after, describes,
# Nearest to use: basis, rest, reparations, because, list, onslaught, measure, drying,
# Nearest to is: was, are, has, be, became, contains, becomes, remains,
# Nearest to were: are, had, was, have, while, although, those, humiliating,
# Nearest to war: foal, overthrow, berthold, humphreys, trade, during, looting, infestation,
# Nearest to which: that, this, what, also, but, usually, often, these,
# Nearest to zero: seven, six, eight, five, nine, three, four, two,
# Nearest to at: during, under, reith, near, in, progressive, on, piacenza,
# Nearest to about: proclamations, dylan, conjunct, around, concerning, empirical, decoy, eucharist,
# Nearest to a: any, another, shaped, the, jackass, every, dreaming, laundering,
# Nearest to s: isbn, kummer, his, chondrite, whose, hyi, slovenes, nimzowitsch,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to that: which, however, what, buttocks, but, where, chronologically, sliced,
# Nearest to time: year, sentiment, period, day, cooperstown, indictment, spicy, kidding,
# Average loss at step 92000: 3.395436
# Average loss at step 94000: 3.252888
# Average loss at step 96000: 3.356982
# Average loss at step 98000: 3.244075
# Average loss at step 100000: 3.355317
# Nearest to they: we, he, there, you, she, it, these, warmer,
# Nearest to during: after, in, before, through, techstep, throughout, when, following,
# Nearest to if: when, where, though, before, describes, although, whether, does,
# Nearest to use: because, usage, basis, reparations, list, indignant, rest, measure,
# Nearest to is: was, has, are, became, becomes, does, remains, be,
# Nearest to were: are, was, have, including, had, these, include, those,
# Nearest to war: overthrow, berthold, foal, humphreys, battle, trade, falk, looting,
# Nearest to which: that, this, what, usually, however, often, who, but,
# Nearest to zero: five, seven, four, six, eight, nine, three, two,
# Nearest to at: during, dismayed, near, under, on, reith, after, jacques,
# Nearest to about: around, dylan, proclamations, concerning, scrambling, conjunct, decoy, empirical,
# Nearest to a: another, any, the, usury, tame, poker, bru, brat,
# Nearest to s: whose, his, isbn, slovenes, the, was, vilas, injector,
# Nearest to will: would, can, could, may, must, should, cannot, might,
# Nearest to that: which, however, what, buttocks, but, following, answered, this,
# Nearest to time: year, period, fibrous, spring, sentiment, happened, salle, indictment,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
